# %%
import glob
import json
import pandas as pd

# %%
json_files = glob.glob('../data/google_places_results/results_*.json')

# %%
def process_json_file(filename):
    with open(filename) as result_file:
        results_json = json.load(result_file)
        results_json_list = []
        for result_json in results_json:
            for result_json_result in result_json['results']:
                result_json_result['orig_mapped_location'] = result_json['mapped_location']
                result_json_result['orig_address'] = result_json['address']
                results_json_list.append(result_json_result)
        return pd.DataFrame(results_json_list)

# %%
frames = [process_json_file(file_path) for file_path in json_files]

# %%
pd.concat(frames)
# Out:
#     business_status                                           geometry  \
# 0       OPERATIONAL  {'location': {'lat': 36.148618, 'lng': -86.807...
# 1       OPERATIONAL  {'location': {'lat': 36.1484482, 'lng': -86.80...
# 2       OPERATIONAL  {'location': {'lat': 36.14815, 'lng': -86.8071...
# 3       OPERATIONAL  {'location': {'lat': 36.1483514, 'lng': -86.80...
# 4       OPERATIONAL  {'location': {'lat': 36.1482875, 'lng': -86.80...
# ..              ...                                                ...
# 495     OPERATIONAL  {'location': {'lat': 36.1524074, 'lng': -86.82...
# 496     OPERATIONAL  {'location': {'lat': 36.15215889999999, 'lng':...
# 497     OPERATIONAL  {'location': {'lat': 36.1521497, 'lng': -86.82...
# 498     OPERATIONAL  {'location': {'lat': 36.1521497, 'lng': -86.82...
# 499     OPERATIONAL  {'location': {'lat': 36.1526462, 'lng': -86.82...
#
#                                                   icon  \
# 0    https://maps.gstatic.com/mapfiles/place_api/ic...
# 1    https://maps.gstatic.com/mapfiles/place_api/ic...
# 2    https://maps.gstatic.com/mapfiles/place_api/ic...
# 3    https://maps.gstatic.com/mapfiles/place_api/ic...
# 4    https://maps.gstatic.com/mapfiles/place_api/ic...
# ..                                                 ...
# 495  https://maps.gstatic.com/mapfiles/place_api/ic...
# 496  https://maps.gstatic.com/mapfiles/place_api/ic...
# 497  https://maps.gstatic.com/mapfiles/place_api/ic...
# 498  https://maps.gstatic.com/mapfiles/place_api/ic...
# 499  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                          name        opening_hours  \
# 0    Martin's Bar-B-Que Joint   {'open_now': True}
# 1                   lunescent                  NaN
# 2                   Music row                  NaN
# 3                  Syntel Inc                  NaN
# 4          Nicholson Cleaners   {'open_now': True}
# ..                        ...                  ...
# 495         Full Ride Cycling   {'open_now': True}
# 496         SandBar Nashville  {'open_now': False}
# 497                 C1TY BLOX                  NaN
# 498             Avocado Mural                  NaN
# 499                       AVO  {'open_now': False}
#
#                                                 photos  \
# 0    [{'height': 5354, 'html_attributions': ['<a hr...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    [{'height': 1536, 'html_attributions': ['<a hr...
# ..                                                 ...
# 495  [{'height': 1448, 'html_attributions': ['<a hr...
# 496  [{'height': 3024, 'html_attributions': ['<a hr...
# 497                                                NaN
# 498                                                NaN
# 499  [{'height': 450, 'html_attributions': ['<a hre...
#
#                         place_id  \
# 0    ChIJ5V0NuYJnZIgRCqjZMw9qlfs
# 1    ChIJT3mJkbtmZIgRnJSG4TiY8yk
# 2    ChIJy_aEQxVnZIgRWFCq1zfFfp0
# 3    ChIJmz2llrtmZIgRfwVcJAVjB4U
# 4    ChIJpbSNjrtmZIgRyF_x9SbRk0M
# ..                           ...
# 495  ChIJb37CeGpnZIgRzbmFrJOzEvM
# 496  ChIJBbL47bRmZIgRkVnyTrTLgwQ
# 497  ChIJJzNDdo9nZIgRU0qZYaf76Vw
# 498  ChIJjeub3khnZIgRjyLN0qpHNLA
# 499  ChIJQXiH47RmZIgRoxorPavBRyo
#
#                                              plus_code  price_level  rating  \
# 0    {'compound_code': '45XV+C3 Nashville, TN, USA'...          2.0     4.4
# 1    {'compound_code': '45XR+9W Nashville, TN, USA'...          NaN     5.0
# 2    {'compound_code': '45XV+74 Nashville, TN, USA'...          NaN     NaN
# 3    {'compound_code': '45XR+8R Nashville, TN, USA'...          NaN     NaN
# 4    {'compound_code': '45XR+8R Nashville, TN, USA'...          NaN     4.2
# ..                                                 ...          ...     ...
# 495  {'compound_code': '552H+XV Nashville, TN, USA'...          NaN     5.0
# 496  {'compound_code': '552H+VW Nashville, TN, USA'...          NaN     4.6
# 497  {'compound_code': '552H+VW Nashville, TN, USA'...          NaN     NaN
# 498  {'compound_code': '552H+VW Nashville, TN, USA'...          NaN     NaN
# 499  {'compound_code': '553H+3X Nashville, TN, USA'...          2.0     4.6
#
#                        reference   scope  \
# 0    ChIJ5V0NuYJnZIgRCqjZMw9qlfs  GOOGLE
# 1    ChIJT3mJkbtmZIgRnJSG4TiY8yk  GOOGLE
# 2    ChIJy_aEQxVnZIgRWFCq1zfFfp0  GOOGLE
# 3    ChIJmz2llrtmZIgRfwVcJAVjB4U  GOOGLE
# 4    ChIJpbSNjrtmZIgRyF_x9SbRk0M  GOOGLE
# ..                           ...     ...
# 495  ChIJb37CeGpnZIgRzbmFrJOzEvM  GOOGLE
# 496  ChIJBbL47bRmZIgRkVnyTrTLgwQ  GOOGLE
# 497  ChIJJzNDdo9nZIgRU0qZYaf76Vw  GOOGLE
# 498  ChIJjeub3khnZIgRjyLN0qpHNLA  GOOGLE
# 499  ChIJQXiH47RmZIgRoxorPavBRyo  GOOGLE
#
#                                                  types  user_ratings_total  \
# 0    [restaurant, food, point_of_interest, establis...               783.0
# 1             [food, point_of_interest, establishment]                 3.0
# 2    [electronics_store, home_goods_store, point_of...                 NaN
# 3                   [point_of_interest, establishment]                 NaN
# 4          [laundry, point_of_interest, establishment]                15.0
# ..                                                 ...                 ...
# 495    [gym, health, point_of_interest, establishment]                53.0
# 496  [bar, restaurant, food, point_of_interest, est...               101.0
# 497                 [point_of_interest, establishment]                 NaN
# 498  [tourist_attraction, point_of_interest, establ...                 NaN
# 499  [bar, restaurant, food, point_of_interest, est...               776.0
#
#                                   vicinity              orig_mapped_location  \
# 0           2400 Elliston Place, Nashville   (36.148664, -86.80740139999999)
# 1          216 Reidhurst Avenue, Nashville   (36.148664, -86.80740139999999)
# 2          2400 West End Avenue, Nashville   (36.148664, -86.80740139999999)
# 3    205 Reidhurst Avenue # 200, Nashville   (36.148664, -86.80740139999999)
# 4           2410 Elliston Place, Nashville   (36.148664, -86.80740139999999)
# ..                                     ...                               ...
# 495  3 City Boulevard Suite 400, Nashville  (36.1524074, -86.82035429999999)
# 496          3 City Avenue #500, Nashville  (36.1524074, -86.82035429999999)
# 497               3 City Avenue, Nashville  (36.1524074, -86.82035429999999)
# 498               3 City Avenue, Nashville  (36.1524074, -86.82035429999999)
# 499          3 City Avenue #200, Nashville  (36.1524074, -86.82035429999999)
#
#                     orig_address permanently_closed
# 0    2400 Elliston Pl, Nashville                NaN
# 1    2400 Elliston Pl, Nashville                NaN
# 2    2400 Elliston Pl, Nashville                NaN
# 3    2400 Elliston Pl, Nashville                NaN
# 4    2400 Elliston Pl, Nashville                NaN
# ..                           ...                ...
# 495       3 City Blvd, Nashville                NaN
# 496       3 City Blvd, Nashville                NaN
# 497       3 City Blvd, Nashville                NaN
# 498       3 City Blvd, Nashville                NaN
# 499       3 City Blvd, Nashville                NaN
#
# [24145 rows x 18 columns]
